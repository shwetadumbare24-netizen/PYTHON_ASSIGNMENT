# %% [markdown]
# 29/07/2026
# Dictionary

# %%
DictOne = {1:"user1", 2:"user2", 3:"user3",1:"user4",4:"user6"}

#students = {"studentOne":55,"studentTwo":56,"studentThree":57,"studnetFour":58}
#print("Dictionary:",DictOne)
#print(students)

#DictOne[4]="user4"

print(DictOne)
print(DictOne[1])

for i in DictOne:
    print(i)
# Out:
# {1: 'user4', 2: 'user2', 3: 'user3', 4: 'user6'}
# user4
# 1
# 2
# 3
# 4

# %%
DictOne = {1:"user1", 2:"user2", 3:"user3",4:"user1",5:{5:True,4:"user6","six":6}}

print(DictOne[5])

DictOne[4] = "user7"
print(DictOne)
# Out:
# {5: True, 4: 'user6', 'six': 6}
# {1: 'user1', 2: 'user2', 3: 'user3', 4: 'user7', 5: {5: True, 4: 'user6', 'six': 6}}
