# %% [markdown]
# str1 = "My name is Demo My friend name is Temp".
# o\p : Remove duplicate element and write Alphabet order

# %%
str1 = "My name is demo. My friend name is temp"
print(str1)
str2 = set(str1)
print(sorted(str2))
# Out:
# My name is demo. My friend name is temp
# [' ', '.', 'M', 'a', 'd', 'e', 'f', 'i', 'm', 'n', 'o', 'p', 'r', 's', 't', 'y']

# %%
str1 = "user Demo User"
str2 = "Demo"

if str2 in str1:
    for i in range(len(str1)):
        if str1[i:i + len(str2)] == str2:
            print(i)
            break
# Out:
# 5

# %% [markdown]
# move zeros(nums)
#
# input=[0,1,0,3,12]
# output=[1,3,12,0,0]

# %%
def move_zero(*nums):
    arr1=[]
    arr2=[]
    for i in nums:
        if i==0:
            arr2.append(i)
        else:
            arr1.append(i)
    res=arr1+arr2
    print(res)
move_zero(0,1,0,3,12)

another method:-
print()
inputstr=[1,3,12,0,0]
listOne=[]
listTwo=[]
for i in inputstr:
    if i==0:
        listTwo.append(i)
    else:
        listOne.append(i)
    print(listOne+listTwo)
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# i/p="banana"
#
# o/p=bnn

# %%
def remove_char(s, char):
    result=""
    for i in s:
        if i!=char:
            result += i
    print(result)
remove_char("banana","a")
# Out:
# bnn

# %%
str1 ="banana"
result= str1.replace("a","")
print(result)
# Out:
# bnn

# %% [markdown]
#     str1=" hello this is magic method "
#
# last word length

# %%
# str1 = " hello this is magic method "
# last word length

str1 = "   hello this is magic method   "
print(len(str1))
words=str1.split()
word=words[-1]
print(len(word))

# %% [markdown]
# input= aaaabbcccc
# output=ccccaaaabb

# %%
str1 = "aaaabbcccc"
char="c"
l1=[]
l2=[]
for i in str1:
    if i == char:
        l2.append(i)
    else:
        l1.append(i)
print(str1)
res="".join(l2+l1)
print(res)
# Out:
# aaaabbcccc
# ccccaaaabb

# %%
#another way:-
str1 = "aaaabbxyzzz"
first=[]
last=[]
for i in str1:
    if i == str1[-1]:
        first.append(i)
    else:
        last.append(i)

print("".join(first+last))
# Out:
# zzzaaaabbxy

# %% [markdown]
# str = python then last two char is on then display ononon

# %%
str="ppython"
strr=""
print("length of char is :-",len(str))
res=str[-2:]
if(len(str)%2==0):
    for i in range(len(str)//2):
        strr += res
        print(strr)
else:
    for i in range(len(str)//2+1):
            strr += res
            print(strr)
# Out:
# length of char is :- 7
# on
# onon
# ononon
# onononon

# %%
str1 = input("Enter string")
print(str1)

if len(str1) % 4 == 0:
    for i in range(0,len(str1), 4):
        print(str1[i:i+4][::-1], end=" ")
else:
    print(str1)

# %% [markdown]
# Example 1:
#
# Input: nums = [3,2,3]
# Output: 3
# Example 2:
#
# Input: nums = [2,2,1,1,1,2,2]
# Output: 2

# %%
class Solution:
    def majorityElement(self, nums):
        n = len(nums)
        for i in nums:
            if nums . count(i) > n // 2:
                return i

# %%
class Solution:
    def majorityElement(self, nums):
        candidate = 0
        count = 0

        for num in nums:
            if count == 0:
                candidate = num

            if num == candidate:
                count += 1
            else:
                count -= 1

        return candidate


obj = Solution()

print(obj.majorityElement([3, 2, 3]))
print(obj.majorityElement([2, 2, 1, 1, 1, 2, 2]))
# Out:
# 3
# 2

# %% [markdown]
# Demo ("[[]]", "abc")
# o/p = [[abc]]

# %%
def demo(pattern , value):
    res = f"[[{value}]]"
    return res
print(demo("[[]]", "abc"))
# Out:
# [[abc]]
