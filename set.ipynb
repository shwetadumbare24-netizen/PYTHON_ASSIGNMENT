# %%
set = {1,3,5,6,8}
print(set)
# Out:
# {1, 3, 5, 6, 8}

# %%
set1 = {"one", "Two" , "Three"}

print(set1)
set1.add("Three")
set1.add("four")
print(set1)
# Out:
# {'one', 'Three', 'Two'}
# {'one', 'four', 'Three', 'Two'}

# %%
set1 = {"one", "Two" , "Three"}#iterable
for i in set1:
    print(i)
# Out:
# one
# Three
# Two

# %%
set1 = {"one", "Two" , "Three",1,23,False}#homo &hetro
for i in set1:
    print(i)

# %%
set1 = {"one", "Two" , ("sonu","xyz"),"Three"}
print(set1)
# Out:
# {'one', ('sonu', 'xyz'), 'Three', 'Two'}

# %%
set1 = {"one","Two","Three"}

set1.add("four")
print(set1)
# Out:
# {'one', 'four', 'Three', 'Two'}

# %%
set1 = {"one","Two","Three"}

print(set1)
set1.clear()
print(set1)

'''set1.remove("Three")
set1.discard("Three")
print(set1)
set1.pop()
print(set1)'''
# Out:
# {'one', 'Three', 'Two'}
# set()
# 'set1.remove("Three")\nset1.discard("Three")\nprint(set1)\nset1.pop()\nprint(set1)'

# %%
set1 = {"one","two","three"}
set2 = {"five","two","seeven"}
print(set1.union(set2))
print(set1.intersection(set2))

print(set1.difference(set2))
print(set2.difference(set1))
# Out:
# {'two', 'three', 'seeven', 'one', 'five'}
# {'two'}
# {'one', 'three'}
# {'five', 'seeven'}

# %%
set1 = {"one","two","three","four"}
nums = {2,4,6,8,7}
print(max(set1))
print(min(set1))
print(sum(nums))
print(sorted(set1))
print(sorted(nums))
print(type(nums))
print(type(set1))
# Out:
# two
# four
# 27
# ['four', 'one', 'three', 'two']
# [2, 4, 6, 7, 8]
# <class 'set'>
# <class 'set'>
