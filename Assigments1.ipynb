# %%
# Personal Profile Program

name = "Shweta Dumbare"
age = 20
college_name = "G.H. Raisoni College of Engineering and Management"
city = "Pune"
course_name = "Artificial Intelligence and Machine Learning"

print("$==========$ Personal Profile $==========$")
print("Name:", name)
print("Age:", age)
print("College Name:", college_name)
print("City:", city)
print("Course Name:", course_name)
# Out:
# $==========$ Personal Profile $==========$
# Name: Shweta Dumbare
# Age: 20
# College Name: G.H. Raisoni College of Engineering and Management
# City: Pune
# Course Name: Artificial Intelligence and Machine Learning

# %%
# Student Report

student_name = "Shweta Dumbare"
roll_number = 101
branch = "Artificial Intelligence and Machine Learning"
percentage = 89.5
passed = True

print("$==========$ Student Report $==========$")
print("Student Name :", student_name)
print("Roll Number :", roll_number)
print("Branch :", branch)
print("Percentage :", percentage)
print("Passed :", passed)
# Out:
# $==========$ Student Report $==========$
# Student Name : Shweta Dumbare
# Roll Number : 101
# Branch : Artificial Intelligence and Machine Learning
# Percentage : 89.5
# Passed : True

# %%
# Identifier Practice

student_name = "Shweta Dumbare"
roll_no = 101
college_name = "GHRCEMP"
branch = "AIML"
semester = 5
attendance = 95
cgpa = 9.54
mobile_number = "9876543210"
email_id = "shweta@gmail.com"
fees_paid = True

print("Student Name :", student_name)
print("Roll No :", roll_no)
print("College Name :", college_name)
print("Branch :", branch)
print("Semester :", semester)
print("Attendance :", attendance)
print("CGPA :", cgpa)
print("Mobile No :", mobile_number)
print("Email ID :", email_id)
print("Fees Paid :", fees_paid)
# Out:
# Student Name : Shweta Dumbare
# Roll No : 101
# College Name : GHRCEMP
# Branch : AIML
# Semester : 5
# Attendance : 95
# CGPA : 9.54
# Mobile No : 9876543210
# Email ID : shweta@gmail.com
# Fees Paid : True

# %%
# This program introduces myself.
# Variables are used to store information.
# Print statements display the output.

"""
This is a multi-line comment.
The program prints a short introduction
about myself using Python.
"""

name = "Shweta Dumbare"
city = "Pune"
course = "Artificial Intelligence and Machine Learning"

print("Hello Everyone!")
print("My name is", name)
print("I am from", city)
print("I am studying", course)
print("I love learning Python programming.")
# Out:
# Hello Everyone!
# My name is Shweta Dumbare
# I am from Pune
# I am studying Artificial Intelligence and Machine Learning
# I love learning Python programming.

# %%
# Corrected Variable Names

student_2 = "Rahul"         
student_name = "Priya"       
student_name2 = "Amit"       
class_name = "AIML-A"       
for_loop = "Python"          
employee_id = 1001           

print("Student 2 :", student_2)
print("Student Name :", student_name)
print("Student Name2:", student_name2)
print("Class Name :", class_name)
print("For Loop :", for_loop)
print("Employee ID :", employee_id)
# Out:
# Student 2 : Rahul
# Student Name : Priya
# Student Name2: Amit
# Class Name : AIML-A
# For Loop : Python
# Employee ID : 1001
