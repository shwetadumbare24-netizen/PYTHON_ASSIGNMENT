# %% [markdown]
# 1. What will be the output of the following code? Explain which namespace Python uses for x.

# %%
x = 10 
def test():
     x = 20     
     print(x)  #20
test() 
print(x) #10
# Out:
# 20
# 10

# %% [markdown]
# 2. What will be the output? Explain the LEGB rule step by step.

# %%
x = "Global"  
def outer():     
    x = "Enclosing"      
    def inner():         
        print(x)      
    inner()  
outer()
print(x)
# Out:
# Enclosing
# Global

# %% [markdown]
# 3. Identify the Local, Enclosing, Global, and Built-in names in the following program:

# %%
x = 10
def outer():
    y = 20
    def inner():
        z = 30
        print(x,y,z,len("Python"))
    inner()
outer()
# Out:
# 10 20 30 6

# %% [markdown]
# 4. What will be the output? Is x being shadowed?

# %%
x = 20

def outer():
    x = 300
   

    def inner():
        x = 500
        print(x)
    inner()
    print(x)

outer()
print(x)
# Out:
# 500
# 300
# 20

# %% [markdown]
# 5. What will happen when this program runs? Explain why.

# %%
count = 10

def update():
    global count
    count = count + 1
    print(count)
update()
# Out:
# 11

# %% [markdown]
# 6. Correct the following program using the global keyword so that the final output is 20

# %%
x = 10 
def update(): 
    global x # This line tells Python that we want to use the global variable x instead of creating a new local variable with the same name.
    x = 20  
update() 
print(x)
# Out:
# 20

# %% [markdown]
# 7. What will be the output? Explain the difference between the Local and Enclosing Namespace.

# %%
def outer():
    x = 10      
    def inner():         
        x = 20         
        print(x)      
    inner()     
    print(x)  
outer()
# Out:
# 20
# 10

# %% [markdown]
# 8. What will be the output? Why does nonlocal change the value of x?

# %%
def outer():
    x = 10
    def inner():
        nonlocal x
        x = 50
        
    inner()
    print(x)
outer()
# Out:
# 20

# %% [markdown]
# 9. Find the error and explain which namespace Python searches before raising the error.

# %%
def outer():
    def inner():
        print(name) # name is not defined in the local or enclosing scope, so it will raise a NameError
    inner()
    
outer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3         print(name) # name is not defined in the local or enclosing scope, so it will raise a NameError
#       4     inner()
# ----> 6 outer()
#
# Cell In[1], line 4, in outer()
#       2 def inner():
#       3     print(name) # name is not defined in the local or enclosing scope, so it will raise a NameError
# ----> 4 inner()
#
# Cell In[1], line 3, in outer.<locals>.inner()
#       2 def inner():
# ----> 3     print(name)
#
# NameError: name 'name' is not defined
