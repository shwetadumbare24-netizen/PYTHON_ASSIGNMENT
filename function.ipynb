# %%
def add (num1,num2):
    res = num1+num2
    print(res)
add(243,243)
add(486,243)
add(2500,243)
# Out:
# 486
# 729
# 2743

# %%
def greet(name,id):
    print("Hello",name)
    print("Hello",id)

greet("Sonu",1)
# Out:
# Hello Sonu
# Hello 1

# %%
def add (num1,num2):
    print(num1+num2)
result = add(10,20)
print(result)
# Out:
# 30
# None

# %%
def add (num1,num2):
    res= num1+num2
    return res
print(add(10,20))
#result = add(10,20)
#print(result)
# Out:
# 30

# %%
def temp(name,roll):
    return name , roll
username , userroll = temp("sonu",1)

print(username , userroll)
#print(temp("sonu",1))
# Out:
# sonu 1

# %% [markdown]
# Default Arguments

# %%
def student(name="temp",roll=0):
    print("student name:",name,"studnet roll no:",roll)
student()
student("mohit",55)
# Out:
# student name: temp studnet roll no: 0
# student name: mohit studnet roll no: 55

# %% [markdown]
# 4. variable length arguments
