# %% [markdown]
# 1. Create a Person parent class with name and age. Create a Student child class with roll_no and marks. Use super() to initialize the parent attributes.

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

class Student(Person):
    def __init__(self,name, age, roll_no, marks):
        super().__init__(name,age)
        self.roll_no = roll_no
        self.marks = marks

s1 = Student("Sonu", 21, 101, 95)
s2 = Student("Rahul", 22, 102, 90)



print("Name:", s1.name, "\nAge:",s1.age,"\nRoll No:",s1.roll_no,"\nMarks:", s1.marks )
print("")
print("Name:",s2.name, "\nAge:",s2.age, "\nRoll No:",s2.roll_no, "\nMarks:",s2.marks)
# Out:
# Name: Sonu
# Age: 21
# Roll No: 101
# Marks: 95
#
# Name: Rahul
# Age: 22
# Roll No: 102
# Marks: 90

# %% [markdown]
# 2. Create a Vehicle parent class with a start() method. Create Car and Bike child classes and override the start() method with different behavior.

# %%
class Vehicle:
    def start(self):
       print("Vehicle is starting")

class Car(Vehicle):
    
    def start(self):
        super().start()
        print("Car starts with key")

class Bike(Vehicle):
    def start(self):
        super().start()
        print("Bike start with self start button")

obj1 = Bike()
obj1.start()

obj2 = Car()
obj2.start()
# Out:
# Vehicle is starting
# Bike start with self start button
# Vehicle is starting
# Car starts with key

# %% [markdown]
# 3. Create an Employee parent class with name and salary. Create a Manager child class with an additional department attribute. Display all details using constructors.

# %%
class Employee:
    def __init__(self,name,salary):
        self.name = name
        self.salary = salary
class Manager(Employee):
    def __init__(self,name,salary,department):
        super().__init__(name,salary)
        self.department = department

m1 = Manager("Shweta",25000,"AIML")
print("Name:",m1.name,"\nSalary:",m1.salary,"\nDepartment:",m1.department)
# Out:
# Name: Shweta
# Salary: 25000
# Department: AIML

# %% [markdown]
# 4. Create a BankAccount parent class with account_number and balance. Create a SavingsAccount child class with an additional interest_rate. Use super() in the child constructor.

# %%
class BankAccount:
    def __init__(self,acc_no,balance):
        self.acc_no = acc_no
        self.balance = balance

class SavingsAccount(BankAccount):
    def __init__(self,acc_no,balance,interest_rate):
        super().__init__(acc_no,balance)
        self.interest_rate = interest_rate

s1 = SavingsAccount(123456,250000, 6.5)

print("Account_NO:",s1.acc_no, "\nBalance:",s1.balance, "\nInterest_rate:",s1.interest_rate)
# Out:
# Account_NO: 123456
# Balance: 250000
# Interest_rate: 6.5

# %% [markdown]
# 5. Create a Person parent class with a display() method. Create a Student child class that overrides display() but also calls the parent display() using super().

# %%
class parson:
    def display(self):
        print("This is parent class")

class Student(parson):
    def display(self):
        super().display()
        print("This is student class")

s1 = Student()
s1.display()
# Out:
# This is parent class
# This is student class

# %% [markdown]
# 6. Create a parent class Company with a company_name attribute. Create two child classes Developer and Tester, each with their own additional attributes and methods.

# %%
class Company:
    def __init__(self,comp_name):
        self.comp_name = comp_name

class Developer(Company):
    def __init__(self,comp_name,programming_language):
        super().__init__(comp_name)
        self.programming_language = programming_language

    def develop(self):
        print("Developing a developer software")

class Tester(Company):
    def __init__(self,comp_name,testing_tool):
        super().__init__(comp_name)
        self.testing_tool = testing_tool

    def test(self):
        print("Tester a testing software")

d1 = Developer("Google","Python")
t1 = Tester("Google","selenium")

print("Developer:")
print("Company:",d1.comp_name)
print("Programming_Language:",d1.programming_language)
d1.develop()
print(" ")

print("Testing:")
print("Company:", t1.comp_name)
print("Testing Tool:", t1.testing_tool)
t1.test()
# Out:
# Developer:
# Company: Google
# Programming_Language: Python
# Developing a developer software
#
# Testing:
# Company: Google
# Testing Tool: selenium
# Tester a testing software

# %% [markdown]
# 7. Bank Account Create a BankAccount class with a private attribute __balance.
#
# Create get_balance() to view the balance.
#
# Create set_balance() to update the balance only if the amount is valid.
#
# Create a withdraw() method with proper balance validation.

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def get_balance(self):
        return self.__balance

    def set_balance(self, amount):
        if amount >= 0:
            self.__balance = amount
            print("Balance updated successfully")
        else:
            print("Invalid amount")

    def withdraw(self, amount):
        if amount <= 0:
            print("Invalid withdrawal amount")
        elif amount > self.__balance:
            print("Insufficient balance")
        else:
            self.__balance -= amount
            print("Withdrawal successful")


account = BankAccount(10000)

print("Balance:", account.get_balance())

account.set_balance(15000)
print("Balance:", account.get_balance())

account.withdraw(5000)
print("Balance:", account.get_balance())

account.withdraw(20000)
# Out:
# Balance: 10000
# Balance updated successfully
# Balance: 15000
# Withdrawal successful
# Balance: 10000
# Insufficient balance

# %% [markdown]
# 8. Student Marks Create a Student class with private attributes __name and __marks.
#
#   Create getter and setter methods for marks.  Allow marks only between 0 and 100.  Create a child class ExamStudent that inherits from Student

# %%
class Student:
    def __init__(self, name, marks):
        self.__name = name
        self.__marks = marks

    def get_name(self):
        return self.__name

    def get_marks(self):
        return self.__marks

    def set_marks(self, marks):
        if 0 <= marks <= 100:
            self.__marks = marks
        else:
            print("Invalid marks!")


class ExamStudent(Student):
    def display(self):
        print("Name of Student:", self.get_name())
        print("Student marks:", self.get_marks())
    def update(self, marks):
        self.set_marks(marks)



s1 = ExamStudent("Sonu", 99)

s1.display()

s1.update(11)

s1.display()
# Out:
# Name of Student: Sonu
# Student marks: 99
# Name of Student: Sonu
# Student marks: 11

# %% [markdown]
# 9. Constructor + Private Data
# Create a User class with private __password.
# Initialize it through the constructor.
# Create get_password() and set_password().
# Setter should update the password only if it contains at least 6 characters.

# %%
class User:
    def __init__(self, password):
        self.__password = password

    def get_password(self):
        return self.__password

    def set_password(self):
        if len(password) >= 6:
            self.__password = password
            print("Password Updated Successfully")
        else:
            print("Invalid Password")

u1 = User("user123")
print("password", u1.get_password())
u1.set_password("abc12345")

print("Updated Password:", u1.get_password())

u1.set_password("abc")
# Out:
# password user123
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 17
#      15 u1 = User("user123")
#      16 print("password", u1.get_password())
# ---> 17 u1.set_password("abc12345")
#      19 print("Updated Password:", u1.get_password())
#      21 u1.set_password("abc")
#
# TypeError: User.set_password() takes 1 positional argument but 2 were given

# %%
class User:
    def __init__(self, password):
        self.__password = password

    def get_password(self):
        return self.__password

    def set_password(self, password):
        if len(password) >= 6:
            self.__password = password
            print("Password updated successfully")
        else:
            print("Password must contain at least 6 characters")


u1 = User("sonu123")

print("Password:", u1.get_password())

u1.set_password("abc234")

print("Updated Password:", u1.get_password())

u1.set_password("abc")
# Out:
# Password: sonu123
# Password updated successfully
# Updated Password: abc234
# Password must contain at least 6 characters

# %% [markdown]
# 10. Multilevel Inheritance + Getter/Setter
#
# Person → private age with getter/setter.  Employee → salary.
# Manager → department.  Use super() at each level

# %%
class Person:
    def __init__(self, age):
        self.__age = age

    def get_age(self):
        return self.__age

    def set_age(self, age):
        if age > 0:
            self.__age = age
        else:
            print("Invalid age")


class Employee(Person):
    def __init__(self, age, salary):
        super().__init__(age)
        self.salary = salary


class Manager(Employee):
    def __init__(self, age, salary, department):
        super().__init__(age, salary)
        self.department = department


m1 = Manager(30, 60000, "IT")

print("Age:", m1.get_age())
print("Salary:", m1.salary)
print("Department:", m1.department)
# Out:
# Age: 30
# Salary: 60000
# Department: IT
