# %%
tupleOne = ("user1","user2","user3")
print(tupleOne[0:2])
# Out:
# ('user1', 'user2')

# %%
tupleOne = ("user1","user2","user3")# used slicing 
print(tupleOne[0:2])
print(tupleOne[::-1])
print(tupleOne[::1])
print(tupleOne[::2])
print(tupleOne[::3])
print(tupleOne[1])
print(tupleOne[-1])
# Out:
# ('user1', 'user2')
# ('user3', 'user2', 'user1')
# ('user1', 'user2', 'user3')
# ('user1', 'user3')
# ('user1',)
# user2
# user3

# %%
tupleOne = ("user1","user2","user3")#iterable
for i in tupleOne:
    print(i, end=" ")
# Out:
# user1 user2 user3

# %%
tupleOne = ("user1","user2","user3","user2","user1")#allow duplicates
print(tupleOne)
# Out:
# ('user1', 'user2', 'user3', 'user2', 'user1')

# %%
tupleOne = ("user1","user2","user3",2,39,True)#Hetro
print(tupleOne)

tupleOne = (True,True,True)#homo
print(tupleOne)
# Out:
# ('user1', 'user2', 'user3', 2, 39, True)
# (True, True, True)

# %%
tupleOne = ("user1","user2",("user3","user2","user3"))#find nested tuple
print(len(tupleOne))
# Out:
# 3

# %%
tupleOne = ("user1","user2","user3","user2","user3")
print(tupleOne[2])
print(tupleOne[-3])
# Out:
# user3
# user3

# %%
tupleOne = ("user1","user2","user3","user2","user3")
tupleTwo = ("user1","user2","user3","user2","user3")
res = tupleOne + tupleTwo
print(res)
print(tupleTwo + tupleOne)
# Out:
# ('user1', 'user2', 'user3', 'user2', 'user3', 'user1', 'user2', 'user3', 'user2', 'user3')
# ('user1', 'user2', 'user3', 'user2', 'user3', 'user1', 'user2', 'user3', 'user2', 'user3')

# %%
tupleTwo = ("user1","user2","user3","user2","user3")
print(tupleOne.count("user2"))
print(tupleOne.count("user3"))
print(tupleOne.index("user2"))
# Out:
# 2
# 2
# 1

# %%
########### Built In Function #############

# %%
tupleTwo = ("user1","user2","user3","user2","user3")
print(len(tupleTwo))
print(max(tupleTwo))
print(min(tupleTwo))
tuple = ("demo","user")
print("d:",ord("d"), "u:", ord("u"))#ascii value
print(max(tuple))
print(min(tuple))
# Out:
# 5
# user3
# user1
# d: 100 u: 117
# user
# demo

# %%
temp = 0 #sum
tup1 = (1,6,7,2,9,5)
for i in tup1:
    temp += i
print(temp)
#print(sum(tup1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 5
#       1 temp = 0 #sum
#       2 #tup1 = (1,6,7,2,9,5)
#       3 #for i in tup1:
#       4     #temp += i
# ----> 5 print(sorted(temp))
#
# TypeError: 'int' object is not iterable

# %%
tup1 = (1,6,7,2,9,5)
print(sorted(tup1))
print(type(tup1))

list1 = list(tup1)
print(list1)

list1 = set(tup1)
print(list1)
# Out:
# [1, 2, 5, 6, 7, 9]
# <class 'tuple'>
# [1, 6, 7, 2, 9, 5]
# {1, 2, 5, 6, 7, 9}

# %%
set1 = (1,6,7,2,9,5)

print(set1)

print(set1[0])

str1 = str(set1)

print(str1)
print(str1[0])
# Out:
# (1, 6, 7, 2, 9, 5)
# 1
# (1, 6, 7, 2, 9, 5)
# (

# %%
tupleTwo = ("user1","user2","user3","user2","user3")

for i, j in enumerate(tupleTwo):
    print(i,j)
# Out:
# 0 user1
# 1 user2
# 2 user3
# 3 user2
# 4 user3

# %%
tupleTwo = ("user1","user2","user3","user2","user3")
print(tupleTwo)
for i , j in enumerate(tupleTwo):
    if  i == 1:
        continue
    print(j)
# Out:
# ('user1', 'user2', 'user3', 'user2', 'user3')
# user1
# user3
# user2
# user3

# %%
tup1 = (1,2,3,4)
print(reversed(tup1))

# %%
tupleOne = (1,True)
tupleTwo = (1,False)
print(any(tupleOne))
print(all(tupleTwo))
# Out:
# True
# False
