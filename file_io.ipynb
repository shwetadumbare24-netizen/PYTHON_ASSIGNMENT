# %%
str = "This is a sample text file."
str1 = "Hello User 2."
file = open("data.txt", "w")

file.write(str)
file.close()

# %%
str = "This is a sample text file."
str1 = "Hello User 2."
file = open("data.txt", "a")

file.write(str)
file.close()

# %%
file = open("data.txt", "r")

content = file.read()
print(content)

file.close()
# Out:
# This is a sample text file.This is a sample text file.

# %%
file = open("data1.txt","x")
file.close()

# %%
str = "temp data"

file = open("data1.txt", "w")
file.write(str)
file.close()

# %%
listOne = ["userone\n", "usertwo\n","userthree\n"]

file = open("temp5.txt", "w")
file.writelines(listOne)
file.close()
